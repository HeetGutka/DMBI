# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use("ggplot")

import sklearn
from sklearn.decomposition import TruncatedSVD

# %%
amazon_ratings = pd.read_csv('Dataset/dataset final.csv')
#amazon_ratings = amazon_ratings.dropna()
amazon_ratings.head()
# Out:
#            userID                    id  productID asins                brand  \
# 0  A39HTATAQ9V7YF  AVpfHrJ6ilAPnD_xVXOI  205616461   NaN                Josmo
# 1  A3JM6GV9MNOF9X  AVpfHrJ6ilAPnD_xVXOI  558925278   NaN                Josmo
# 2  A1Z513UWSAAO0F  AVpfHsWP1cnluZ0-eVZ7  558925278   NaN  SERVUS BY HONEYWELL
# 3  A1WMRR494NWEWV  AVpfHsWP1cnluZ0-eVZ7  733001998   NaN  SERVUS BY HONEYWELL
# 4  A3IAAVS479H7M7  AVpfHsWP1cnluZ0-eVZ7  737104473   NaN  SERVUS BY HONEYWELL
#
#                                    categories colors  count  \
# 0  Clothing,Shoes,Men's Shoes,All Men's Shoes    NaN    NaN
# 1  Clothing,Shoes,Men's Shoes,All Men's Shoes    NaN    NaN
# 2  All Men's Shoes,Shoes,Men's Shoes,Clothing    NaN    NaN
# 3  All Men's Shoes,Shoes,Men's Shoes,Clothing    NaN    NaN
# 4  All Men's Shoes,Shoes,Men's Shoes,Clothing    NaN    NaN
#
#               dateAdded           dateUpdated  ...       prices.offer  \
# 0  2016-11-07T00:45:12Z  2016-11-07T00:45:12Z  ...  REDUCED USD 12.10
# 1  2016-11-07T00:45:12Z  2016-11-07T00:45:12Z  ...  REDUCED USD 12.10
# 2  2016-06-14T04:29:57Z  2016-07-09T20:26:48Z  ...                NaN
# 3  2016-06-14T04:29:57Z  2016-07-09T20:26:48Z  ...                NaN
# 4  2016-06-14T04:29:57Z  2016-07-09T20:26:48Z  ...                NaN
#
#   prices.shipping                                  prices.sourceURLs reviews  \
# 0             NaN  https://www.walmart.com/ip/Josmo-8190-Plain-In...     NaN
# 1             NaN  https://www.walmart.com/ip/Josmo-8190-Plain-In...     NaN
# 2             NaN  http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...     NaN
# 3             NaN  http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...     NaN
# 4             NaN  http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...     NaN
#
#   sizes skus                                         sourceURLs       upc  \
# 0   NaN  NaN  https://www.walmart.com/ip/Josmo-8190-Plain-In...  6.99E+11
# 1   NaN  NaN  https://www.walmart.com/ip/Josmo-8190-Plain-In...  6.99E+11
# 2   NaN  NaN  http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...       NaN
# 3   NaN  NaN  http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...       NaN
# 4   NaN  NaN  http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...       NaN
#
#   ratings   timestamp
# 0       5  1369699200
# 1       3  1355443200
# 2       5  1404691200
# 3       4  1382572800
# 4       1  1274227200
#
# [5 rows x 38 columns]

# %%
amazon_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1068 entries, 0 to 1067
# Data columns (total 38 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   userID              1068 non-null   object
#  1   id                  1068 non-null   object
#  2   productID           1068 non-null   object
#  3   asins               116 non-null    object
#  4   brand               1061 non-null   object
#  5   categories          1068 non-null   object
#  6   colors              604 non-null    object
#  7   count               0 non-null      float64
#  8   dateAdded           1068 non-null   object
#  9   dateUpdated         1068 non-null   object
#  10  descriptions        573 non-null    object
#  11  dimension           150 non-null    object
#  12  ean                 596 non-null    float64
#  13  features            818 non-null    object
#  14  imageURLs           1001 non-null   object
#  15  keys                1068 non-null   object
#  16  manufacturer        380 non-null    object
#  17  manufacturerNumber  817 non-null    object
#  18  merchants           772 non-null    object
#  19  name                1068 non-null   object
#  20  prices.amountMin    1068 non-null   float64
#  21  prices.amountMax    1068 non-null   float64
#  22  prices.condition    674 non-null    object
#  23  prices.currency     1068 non-null   object
#  24  prices.dateAdded    1068 non-null   object
#  25  prices.dateSeen     1068 non-null   object
#  26  prices.isSale       1064 non-null   object
#  27  prices.merchant     718 non-null    object
#  28  prices.offer        386 non-null    object
#  29  prices.shipping     282 non-null    object
#  30  prices.sourceURLs   1063 non-null   object
#  31  reviews             100 non-null    object
#  32  sizes               333 non-null    object
#  33  skus                454 non-null    object
#  34  sourceURLs          1065 non-null   object
#  35  upc                 639 non-null    object
#  36  ratings             1068 non-null   int64
#  37  timestamp           1068 non-null   int64
# dtypes: float64(4), int64(2), object(32)
# memory usage: 183.6+ KB

# %%
amazon_ratings['count'] = amazon_ratings['count'].apply(lambda x:np.random.randint(1, 10))

# %%
amazon_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1068 entries, 0 to 1067
# Data columns (total 38 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   userID              1068 non-null   object
#  1   id                  1068 non-null   object
#  2   productID           1068 non-null   object
#  3   asins               116 non-null    object
#  4   brand               1061 non-null   object
#  5   categories          1068 non-null   object
#  6   colors              604 non-null    object
#  7   count               1068 non-null   int64
#  8   dateAdded           1068 non-null   object
#  9   dateUpdated         1068 non-null   object
#  10  descriptions        573 non-null    object
#  11  dimension           150 non-null    object
#  12  ean                 596 non-null    float64
#  13  features            818 non-null    object
#  14  imageURLs           1001 non-null   object
#  15  keys                1068 non-null   object
#  16  manufacturer        380 non-null    object
#  17  manufacturerNumber  817 non-null    object
#  18  merchants           772 non-null    object
#  19  name                1068 non-null   object
#  20  prices.amountMin    1068 non-null   float64
#  21  prices.amountMax    1068 non-null   float64
#  22  prices.condition    674 non-null    object
#  23  prices.currency     1068 non-null   object
#  24  prices.dateAdded    1068 non-null   object
#  25  prices.dateSeen     1068 non-null   object
#  26  prices.isSale       1064 non-null   object
#  27  prices.merchant     718 non-null    object
#  28  prices.offer        386 non-null    object
#  29  prices.shipping     282 non-null    object
#  30  prices.sourceURLs   1063 non-null   object
#  31  reviews             100 non-null    object
#  32  sizes               333 non-null    object
#  33  skus                454 non-null    object
#  34  sourceURLs          1065 non-null   object
#  35  upc                 639 non-null    object
#  36  ratings             1068 non-null   int64
#  37  timestamp           1068 non-null   int64
# dtypes: float64(3), int64(3), object(32)
# memory usage: 183.6+ KB

# %%
amazon_ratings
# Out:
#               userID                    id   productID asins  \
# 0     A39HTATAQ9V7YF  AVpfHrJ6ilAPnD_xVXOI   205616461   NaN
# 1     A3JM6GV9MNOF9X  AVpfHrJ6ilAPnD_xVXOI   558925278   NaN
# 2     A1Z513UWSAAO0F  AVpfHsWP1cnluZ0-eVZ7   558925278   NaN
# 3     A1WMRR494NWEWV  AVpfHsWP1cnluZ0-eVZ7   733001998   NaN
# 4     A3IAAVS479H7M7  AVpfHsWP1cnluZ0-eVZ7   737104473   NaN
# ...              ...                   ...         ...   ...
# 1063  A3OFKO6HR06L0V  AVpfHJSGilAPnD_xVMFU  9790771010   NaN
# 1064  A3KL8WSLJPSWMR  AVpe7cFYilAPnD_xRF9d  9790771339   NaN
# 1065   AHUQSDM26UH5C  AVpfVKLGilAPnD_xZxjH  9790771347   NaN
# 1066   ATJ6S9R0W10JS  AVpfVB2E1cnluZ0-it1Q  9790771401   NaN
# 1067  A3KT64AAQTXIG0  AVpfVB2E1cnluZ0-it1Q  9790771401   NaN
#
#                     brand                                         categories  \
# 0                   Josmo         Clothing,Shoes,Men's Shoes,All Men's Shoes
# 1                   Josmo         Clothing,Shoes,Men's Shoes,All Men's Shoes
# 2     SERVUS BY HONEYWELL         All Men's Shoes,Shoes,Men's Shoes,Clothing
# 3     SERVUS BY HONEYWELL         All Men's Shoes,Shoes,Men's Shoes,Clothing
# 4     SERVUS BY HONEYWELL         All Men's Shoes,Shoes,Men's Shoes,Clothing
# ...                   ...                                                ...
# 1063                 PUMA      Men's Casual Shoes,Shoes,Men's Shoes,Clothing
# 1064                 Nike  Clothing, Shoes & Accessories,Men's Shoes,Athl...
# 1065             SKECHERS      Men's Casual Shoes,Shoes,Men's Shoes,Clothing
# 1066         Georgia Boot  Home Improvement,Men's Work & Safety Shoes,All...
# 1067         Georgia Boot  Home Improvement,Men's Work & Safety Shoes,All...
#
#            colors  count             dateAdded           dateUpdated  ...  \
# 0             NaN      9  2016-11-07T00:45:12Z  2016-11-07T00:45:12Z  ...
# 1             NaN      6  2016-11-07T00:45:12Z  2016-11-07T00:45:12Z  ...
# 2             NaN      9  2016-06-14T04:29:57Z  2016-07-09T20:26:48Z  ...
# 3             NaN      9  2016-06-14T04:29:57Z  2016-07-09T20:26:48Z  ...
# 4             NaN      7  2016-06-14T04:29:57Z  2016-07-09T20:26:48Z  ...
# ...           ...    ...                   ...                   ...  ...
# 1063        White      3  2016-11-15T13:14:59Z  2016-11-15T13:14:59Z  ...
# 1064  Multi-Color      8  2016-03-04T05:43:58Z  2016-03-04T05:43:58Z  ...
# 1065          NaN      5  2016-11-11T09:46:36Z  2016-11-11T09:46:36Z  ...
# 1066          NaN      9  2016-02-25T21:08:16Z  2016-06-08T05:29:32Z  ...
# 1067          NaN      1  2016-02-25T21:08:16Z  2016-06-08T05:29:32Z  ...
#
#            prices.offer prices.shipping  \
# 0     REDUCED USD 12.10             NaN
# 1     REDUCED USD 12.10             NaN
# 2                   NaN             NaN
# 3                   NaN             NaN
# 4                   NaN             NaN
# ...                 ...             ...
# 1063  REDUCED USD 23.02             NaN
# 1064                NaN             NaN
# 1065                NaN             NaN
# 1066                NaN             NaN
# 1067                NaN             NaN
#
#                                       prices.sourceURLs reviews sizes  \
# 0     https://www.walmart.com/ip/Josmo-8190-Plain-In...     NaN   NaN
# 1     https://www.walmart.com/ip/Josmo-8190-Plain-In...     NaN   NaN
# 2     http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...     NaN   NaN
# 3     http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...     NaN   NaN
# 4     http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...     NaN   NaN
# ...                                                 ...     ...   ...
# 1063  https://www.walmart.com/ip/Puma-evoSpeed-1-4-S...     NaN    12
# 1064  http://www.ebay.com/itm/New-Mens-Nike-Jordan-E...     NaN    10
# 1065  https://www.walmart.com/ip/SKECHERS-77066-BLK-...     NaN   NaN
# 1066  http://www.walmart.com/ip/GEORGIA-BOOT-G4374-9...     NaN   NaN
# 1067  http://www.walmart.com/ip/GEORGIA-BOOT-G4374-9...     NaN   NaN
#
#                                                    skus  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1063                                                NaN
# 1064  [{"sourceURLs":["http://www.ebay.com/itm/New-M...
# 1065                                                NaN
# 1066                                                NaN
# 1067                                                NaN
#
#                                              sourceURLs       upc ratings  \
# 0     https://www.walmart.com/ip/Josmo-8190-Plain-In...  6.99E+11       5
# 1     https://www.walmart.com/ip/Josmo-8190-Plain-In...  6.99E+11       3
# 2     http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...       NaN       5
# 3     http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...       NaN       4
# 4     http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...       NaN       1
# ...                                                 ...       ...     ...
# 1063  https://www.walmart.com/ip/Puma-evoSpeed-1-4-S...  8.89E+11       2
# 1064  http://www.ebay.com/itm/New-Mens-Nike-Jordan-E...  8.88E+11       5
# 1065  https://www.walmart.com/ip/SKECHERS-77066-BLK-...       NaN       3
# 1066  http://www.walmart.com/ip/GEORGIA-BOOT-G4374-9...       NaN       5
# 1067  http://www.walmart.com/ip/GEORGIA-BOOT-G4374-9...       NaN       5
#
#        timestamp
# 0     1369699200
# 1     1355443200
# 2     1404691200
# 3     1382572800
# 4     1274227200
# ...          ...
# 1063  1358467200
# 1064  1355011200
# 1065  1348790400
# 1066  1389398400
# 1067  1386374400
#
# [1068 rows x 38 columns]

# %%
amazon_ratings = amazon_ratings.fillna(0)

# %%
amazon_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1068 entries, 0 to 1067
# Data columns (total 38 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   userID              1068 non-null   object
#  1   id                  1068 non-null   object
#  2   productID           1068 non-null   object
#  3   asins               1068 non-null   object
#  4   brand               1068 non-null   object
#  5   categories          1068 non-null   object
#  6   colors              1068 non-null   object
#  7   count               1068 non-null   int64
#  8   dateAdded           1068 non-null   object
#  9   dateUpdated         1068 non-null   object
#  10  descriptions        1068 non-null   object
#  11  dimension           1068 non-null   object
#  12  ean                 1068 non-null   float64
#  13  features            1068 non-null   object
#  14  imageURLs           1068 non-null   object
#  15  keys                1068 non-null   object
#  16  manufacturer        1068 non-null   object
#  17  manufacturerNumber  1068 non-null   object
#  18  merchants           1068 non-null   object
#  19  name                1068 non-null   object
#  20  prices.amountMin    1068 non-null   float64
#  21  prices.amountMax    1068 non-null   float64
#  22  prices.condition    1068 non-null   object
#  23  prices.currency     1068 non-null   object
#  24  prices.dateAdded    1068 non-null   object
#  25  prices.dateSeen     1068 non-null   object
#  26  prices.isSale       1068 non-null   object
#  27  prices.merchant     1068 non-null   object
#  28  prices.offer        1068 non-null   object
#  29  prices.shipping     1068 non-null   object
#  30  prices.sourceURLs   1068 non-null   object
#  31  reviews             1068 non-null   object
#  32  sizes               1068 non-null   object
#  33  skus                1068 non-null   object
#  34  sourceURLs          1068 non-null   object
#  35  upc                 1068 non-null   object
#  36  ratings             1068 non-null   int64
#  37  timestamp           1068 non-null   int64
# dtypes: float64(3), int64(3), object(32)
# memory usage: 183.6+ KB

# %%
amazon_ratings
# Out:
#               userID                    id   productID asins  \
# 0     A39HTATAQ9V7YF  AVpfHrJ6ilAPnD_xVXOI   205616461     0
# 1     A3JM6GV9MNOF9X  AVpfHrJ6ilAPnD_xVXOI   558925278     0
# 2     A1Z513UWSAAO0F  AVpfHsWP1cnluZ0-eVZ7   558925278     0
# 3     A1WMRR494NWEWV  AVpfHsWP1cnluZ0-eVZ7   733001998     0
# 4     A3IAAVS479H7M7  AVpfHsWP1cnluZ0-eVZ7   737104473     0
# ...              ...                   ...         ...   ...
# 1063  A3OFKO6HR06L0V  AVpfHJSGilAPnD_xVMFU  9790771010     0
# 1064  A3KL8WSLJPSWMR  AVpe7cFYilAPnD_xRF9d  9790771339     0
# 1065   AHUQSDM26UH5C  AVpfVKLGilAPnD_xZxjH  9790771347     0
# 1066   ATJ6S9R0W10JS  AVpfVB2E1cnluZ0-it1Q  9790771401     0
# 1067  A3KT64AAQTXIG0  AVpfVB2E1cnluZ0-it1Q  9790771401     0
#
#                     brand                                         categories  \
# 0                   Josmo         Clothing,Shoes,Men's Shoes,All Men's Shoes
# 1                   Josmo         Clothing,Shoes,Men's Shoes,All Men's Shoes
# 2     SERVUS BY HONEYWELL         All Men's Shoes,Shoes,Men's Shoes,Clothing
# 3     SERVUS BY HONEYWELL         All Men's Shoes,Shoes,Men's Shoes,Clothing
# 4     SERVUS BY HONEYWELL         All Men's Shoes,Shoes,Men's Shoes,Clothing
# ...                   ...                                                ...
# 1063                 PUMA      Men's Casual Shoes,Shoes,Men's Shoes,Clothing
# 1064                 Nike  Clothing, Shoes & Accessories,Men's Shoes,Athl...
# 1065             SKECHERS      Men's Casual Shoes,Shoes,Men's Shoes,Clothing
# 1066         Georgia Boot  Home Improvement,Men's Work & Safety Shoes,All...
# 1067         Georgia Boot  Home Improvement,Men's Work & Safety Shoes,All...
#
#            colors  count             dateAdded           dateUpdated  ...  \
# 0               0      9  2016-11-07T00:45:12Z  2016-11-07T00:45:12Z  ...
# 1               0      6  2016-11-07T00:45:12Z  2016-11-07T00:45:12Z  ...
# 2               0      9  2016-06-14T04:29:57Z  2016-07-09T20:26:48Z  ...
# 3               0      9  2016-06-14T04:29:57Z  2016-07-09T20:26:48Z  ...
# 4               0      7  2016-06-14T04:29:57Z  2016-07-09T20:26:48Z  ...
# ...           ...    ...                   ...                   ...  ...
# 1063        White      3  2016-11-15T13:14:59Z  2016-11-15T13:14:59Z  ...
# 1064  Multi-Color      8  2016-03-04T05:43:58Z  2016-03-04T05:43:58Z  ...
# 1065            0      5  2016-11-11T09:46:36Z  2016-11-11T09:46:36Z  ...
# 1066            0      9  2016-02-25T21:08:16Z  2016-06-08T05:29:32Z  ...
# 1067            0      1  2016-02-25T21:08:16Z  2016-06-08T05:29:32Z  ...
#
#            prices.offer prices.shipping  \
# 0     REDUCED USD 12.10               0
# 1     REDUCED USD 12.10               0
# 2                     0               0
# 3                     0               0
# 4                     0               0
# ...                 ...             ...
# 1063  REDUCED USD 23.02               0
# 1064                  0               0
# 1065                  0               0
# 1066                  0               0
# 1067                  0               0
#
#                                       prices.sourceURLs reviews sizes  \
# 0     https://www.walmart.com/ip/Josmo-8190-Plain-In...       0     0
# 1     https://www.walmart.com/ip/Josmo-8190-Plain-In...       0     0
# 2     http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...       0     0
# 3     http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...       0     0
# 4     http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...       0     0
# ...                                                 ...     ...   ...
# 1063  https://www.walmart.com/ip/Puma-evoSpeed-1-4-S...       0    12
# 1064  http://www.ebay.com/itm/New-Mens-Nike-Jordan-E...       0    10
# 1065  https://www.walmart.com/ip/SKECHERS-77066-BLK-...       0     0
# 1066  http://www.walmart.com/ip/GEORGIA-BOOT-G4374-9...       0     0
# 1067  http://www.walmart.com/ip/GEORGIA-BOOT-G4374-9...       0     0
#
#                                                    skus  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 1063                                                  0
# 1064  [{"sourceURLs":["http://www.ebay.com/itm/New-M...
# 1065                                                  0
# 1066                                                  0
# 1067                                                  0
#
#                                              sourceURLs       upc ratings  \
# 0     https://www.walmart.com/ip/Josmo-8190-Plain-In...  6.99E+11       5
# 1     https://www.walmart.com/ip/Josmo-8190-Plain-In...  6.99E+11       3
# 2     http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...         0       5
# 3     http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...         0       4
# 4     http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...         0       1
# ...                                                 ...       ...     ...
# 1063  https://www.walmart.com/ip/Puma-evoSpeed-1-4-S...  8.89E+11       2
# 1064  http://www.ebay.com/itm/New-Mens-Nike-Jordan-E...  8.88E+11       5
# 1065  https://www.walmart.com/ip/SKECHERS-77066-BLK-...         0       3
# 1066  http://www.walmart.com/ip/GEORGIA-BOOT-G4374-9...         0       5
# 1067  http://www.walmart.com/ip/GEORGIA-BOOT-G4374-9...         0       5
#
#        timestamp
# 0     1369699200
# 1     1355443200
# 2     1404691200
# 3     1382572800
# 4     1274227200
# ...          ...
# 1063  1358467200
# 1064  1355011200
# 1065  1348790400
# 1066  1389398400
# 1067  1386374400
#
# [1068 rows x 38 columns]

# %%
amazon_ratings.shape
# Out:
# (1068, 38)

# %%
popular_products = pd.DataFrame(amazon_ratings.groupby('productID')['ratings'].count())
most_popular = popular_products.sort_values('ratings', ascending=False)
most_popular.head(10)
# Out:
#             ratings
# productID
# 9746427962       41
# 9759091062       40
# 9788071198       36
# 7806397051       35
# 9788072216       34
# 3227001381       25
# 9788073409       20
# 9788073840       20
# 9748776093       19
# 7535842801       17

# %%
most_popular.head(30).plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='productID'>

# %%
ratings_utility_matrix = amazon_ratings.pivot_table(values='ratings', index='userID', columns='productID', fill_value=0)
ratings_utility_matrix.head()
# Out:
# productID              1304139212  1304139220  130414089X  130414643X  \
# userID
# A00205921JHJK5X9LNP42           0           0           0           0
# A024581134CV80ZBLIZTZ           0           0           0           0
# A05492663T95KW63BR75K           0           0           0           0
# A100GYE1W4OXZ8                  0           0           0           0
# A10205RFE66H1R                  0           0           0           0
#
# productID              1304146537  130414674X  1304168522  1304174778  \
# userID
# A00205921JHJK5X9LNP42           0           0           0           0
# A024581134CV80ZBLIZTZ           0           0           0           0
# A05492663T95KW63BR75K           0           0           0           0
# A100GYE1W4OXZ8                  0           0           0           0
# A10205RFE66H1R                  0           0           0           0
#
# productID              1304174867  1304174905  ...  9790770839  9790770871  \
# userID                                         ...
# A00205921JHJK5X9LNP42           0           0  ...           0           0
# A024581134CV80ZBLIZTZ           0           0  ...           0           0
# A05492663T95KW63BR75K           0           0  ...           0           0
# A100GYE1W4OXZ8                  0           0  ...           0           0
# A10205RFE66H1R                  0           0  ...           0           0
#
# productID              9790770898  9790770944  9790770995  9790771002  \
# userID
# A00205921JHJK5X9LNP42           0           0           0           0
# A024581134CV80ZBLIZTZ           0           0           0           0
# A05492663T95KW63BR75K           0           0           0           0
# A100GYE1W4OXZ8                  0           0           0           0
# A10205RFE66H1R                  0           0           0           0
#
# productID              9790771010  9790771339  9790771347  9790771401
# userID
# A00205921JHJK5X9LNP42           0           0           0           0
# A024581134CV80ZBLIZTZ           0           0           0           0
# A05492663T95KW63BR75K           0           0           0           0
# A100GYE1W4OXZ8                  0           0           0           0
# A10205RFE66H1R                  0           0           0           0
#
# [5 rows x 295 columns]

# %%
ratings_utility_matrix.shape
# Out:
# (1016, 295)

# %%
X = ratings_utility_matrix.T
X.head()
# Out:
# userID      A00205921JHJK5X9LNP42  A024581134CV80ZBLIZTZ  \
# productID
# 1304139212                      0                      0
# 1304139220                      0                      0
# 130414089X                      0                      0
# 130414643X                      0                      0
# 1304146537                      0                      0
#
# userID      A05492663T95KW63BR75K  A100GYE1W4OXZ8  A10205RFE66H1R  \
# productID
# 1304139212                      0               0               0
# 1304139220                      0               0               0
# 130414089X                      0               0               0
# 130414643X                      0               0               0
# 1304146537                      0               0               0
#
# userID      A104D62WJII6KP  A108HJD2ESJXUY  A10GKM76NOQLGE  A10R4813UIW6GH  \
# productID
# 1304139212               0               0               0               0
# 1304139220               0               0               0               0
# 130414089X               0               0               0               0
# 130414643X               0               0               0               0
# 1304146537               0               0               0               0
#
# userID      A10REFE1TW3ZVT  ...  AYI1LDJYGG0ZK  AYM7E80UCJX7I  AYTK85H56WQ5F  \
# productID                   ...
# 1304139212               0  ...              0              0              0
# 1304139220               0  ...              0              0              0
# 130414089X               0  ...              0              0              0
# 130414643X               0  ...              0              0              0
# 1304146537               0  ...              0              0              0
#
# userID      AYYB9EFFG2GVA  AZ4FR14IPKML7  AZGGH4GS18RUN  AZLE2XFH3JUNG  \
# productID
# 1304139212              0              0              0              0
# 1304139220              0              0              0              0
# 130414089X              0              0              0              0
# 130414643X              0              0              0              0
# 1304146537              0              0              0              0
#
# userID      AZLYAJ8XE443K  AZWRTJPN7NXT  AZYQEFB9Y5N22
# productID
# 1304139212              0             0              0
# 1304139220              0             0              0
# 130414089X              0             0              0
# 130414643X              0             0              0
# 1304146537              0             0              0
#
# [5 rows x 1016 columns]

# %%
X.shape
# Out:
# (295, 1016)

# %%
X1 = X

# %%
SVD = TruncatedSVD(n_components=10)
decomposed_matrix = SVD.fit_transform(X)
decomposed_matrix.shape
# Out:
# (295, 10)

# %%
correlation_matrix = np.corrcoef(decomposed_matrix)
correlation_matrix.shape
# Out:
# (295, 295)

# %%
X.index[199]
# Out:
# '9788072119'

# %%
i = "9788072119"

product_names = list(X.index)
product_ID = product_names.index(i)
product_ID
# Out:
# 199

# %%
correlation_product_ID = correlation_matrix[product_ID]
correlation_product_ID.shape
# Out:
# (295,)

# %%
Recommend = list(X.index[correlation_product_ID > 0.90])

# Removes the item already bought by the customer
Recommend.remove(i) 

Recommend[0:15]
# Out:
# ['5297000963', '9788071570', '9788072097']
